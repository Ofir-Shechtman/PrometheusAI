# %%
from prometheus_api_client import PrometheusConnect
from prometheus_api_client.metric_range_df import MetricRangeDataFrame
from prometheus_api_client.utils import parse_datetime
from datetime import timedelta
import pandas as pd

# %%
operate_first_token = "sha256~Cg4oQ5qOWfUWNuWisJOuEyNOsD4A6Yed-SRxG-8APKM"
thanos_url = 'https://thanos-query-frontend-opf-observatorium.apps.smaug.na.operate-first.cloud'
pc = PrometheusConnect(
  url= thanos_url,
  headers= {"Authorization": f"Bearer {operate_first_token}"},
  disable_ssl=False
)
pd.DataFrame(pc.all_metrics(), columns={"metrics"})
# Out:
#                                            metrics
# 0              :node_memory_MemAvailable_bytes:sum
# 1                                           ALERTS
# 2                                 ALERTS_FOR_STATE
# 3           NooBaa_BGWorkers_nodejs_active_handles
# 4     NooBaa_BGWorkers_nodejs_active_handles_total
# ...                                            ...
# 4031                           zookeeper_sslquorum
# 4032                           zookeeper_synclimit
# 4033                                zookeeper_tick
# 4034                            zookeeper_ticktime
# 4035               zookeeper_txnlogelapsedsynctime
#
# [4036 rows x 1 columns]

# %%
pc.get_current_metric_value("http_requests_total")
# Out:
# [{'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '379']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '375']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_names',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '40']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_names',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '49']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '59']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '77']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'metadata',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '36']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'metadata',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '55']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '8499']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '53486']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '4026']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '53544']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '13046']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '1050']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '15589']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '1134']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'react-static',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '44623']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '21396']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '140']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '146']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'status_flags',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'stores',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '400',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '400',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '8']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.3.102:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-hcfl7',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '5']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '500',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/balrog',
#    'code': '503',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.2.215:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-6488c54674-5d8rl',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-balrog'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '36']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '45']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_names',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '22']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_names',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '14']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '23']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '36']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'metadata',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '23']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'metadata',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '13']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '101202']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '52780']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '93748']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '52319']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '142887']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '91']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '154476']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '93']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'react-static',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '21879']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '26927']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.128.2.47:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-hqpnj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '40']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '40']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'status_flags',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'emea/rick',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'stores',
#    'instance': '10.131.0.37:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-5b64ddb796-xnvk6',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'emea-rick'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '882']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '470576']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '1072']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '133382']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '66']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '961']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '315']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '5370']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.128.0.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-8zwvd',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '14']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/infra',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.130.0.70:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-69d86d997-qf4fp',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-infra'},
#   'value': [1639921537.004, '8']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'exemplars',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '8']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_names',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'label_values',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'metadata',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '38289']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '105879']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '29967']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '333787']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '43413']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '9766']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '146068']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1204']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'react-static',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '5930']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '24629']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '21']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'series',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '22']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'status_flags',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'stores',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'exemplars',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'exemplars',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-n2v76',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-n2v76',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '6']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'exemplars',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-zps9z',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-zps9z',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '7']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'label_names',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'label_values',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '4']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'label_values',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-n2v76',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-n2v76',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '5']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'label_values',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-zps9z',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-zps9z',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '6']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'metadata',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-zps9z',
#    'job': 'observatorium-thanos-query',
#    'method': 'get',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-zps9z',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query_range',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
# ...
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2888586']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1555828']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '1555853']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-ruler-proxy',
#    'endpoint': 'web',
#    'handler': 'react-static',
#    'instance': '10.129.8.18:9091',
#    'job': 'thanos-ruler',
#    'method': 'get',
#    'namespace': 'openshift-user-workload-monitoring',
#    'pod': 'thanos-ruler-user-workload-1',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-ruler',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '200',
#    'container': 'thanos-ruler-proxy',
#    'endpoint': 'web',
#    'handler': 'rules',
#    'instance': '10.129.8.18:9091',
#    'job': 'thanos-ruler',
#    'method': 'get',
#    'namespace': 'openshift-user-workload-monitoring',
#    'pod': 'thanos-ruler-user-workload-1',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-ruler',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '1']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-0',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-0',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '551']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-0',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-0',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '551']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2059']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2059']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '375']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '409',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '375']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '28']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '89']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.129.8.14:9091',
#    'job': 'thanos-querier',
#    'method': 'post',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-4k2xj',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '103']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'oauth-proxy',
#    'endpoint': 'web',
#    'handler': 'query_range',
#    'instance': '10.131.2.11:9091',
#    'job': 'thanos-querier',
#    'method': 'get',
#    'namespace': 'openshift-monitoring',
#    'pod': 'thanos-querier-76ff896c99-5rrp2',
#    'prometheus': 'openshift-monitoring/k8s',
#    'service': 'thanos-querier',
#    'tenant_id': 'moc-smaug'},
#   'value': [1639921537.004, '209']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query_range',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-54nfh',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-54nfh',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '15']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query_range',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-n2v76',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-n2v76',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '18']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '422',
#    'container': 'thanos-query',
#    'endpoint': 'http',
#    'handler': 'query_range',
#    'instance': 'opf-observatorium/observatorium-thanos-query-7cd455797c-zps9z',
#    'job': 'observatorium-thanos-query',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-7cd455797c-zps9z',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '8']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '499',
#    'container': 'thanos-query-frontend',
#    'endpoint': 'http',
#    'handler': 'query-frontend',
#    'instance': 'opf-observatorium/observatorium-thanos-query-frontend-65656f558c-c4qqj',
#    'job': 'observatorium-thanos-query-frontend',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-query-frontend-65656f558c-c4qqj',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-query-frontend',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '44']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '500',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '500',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '3']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-0',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-0',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '356']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-0',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-0',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '356']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '97839']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-1',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-1',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '97839']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2']},
#  {'metric': {'__name__': 'http_requests_total',
#    'cluster': 'moc/smaug',
#    'code': '503',
#    'container': 'thanos-receive',
#    'endpoint': 'http',
#    'handler': 'receive',
#    'instance': 'opf-observatorium/observatorium-thanos-receive-default-2',
#    'job': 'observatorium-thanos-receive-default',
#    'method': 'post',
#    'namespace': 'opf-observatorium',
#    'pod': 'observatorium-thanos-receive-default-2',
#    'prometheus': 'openshift-user-workload-monitoring/user-workload',
#    'service': 'observatorium-thanos-receive-default',
#    'tenant_id': 'moc-smaug-uwm'},
#   'value': [1639921537.004, '2']}]
